# %% [markdown]
# # Two-Layer Grid

# %%
using DifferentialEquations
using LightGraphs
using GraphRecipes
using Statistics
using LaTeXStrings
using Plots
using LinearAlgebra
using Plotly
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-3601818828643509207\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-17901326463260677406\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-3601818828643509207\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %%
g1=CompleteGraph(20)
int=Int(nv(g1)/2)
for i in 1:int
    for j in (int+1):Int(2*int)
        rem_edge!(g1,i,j)
    end
    add_edge!(g1,i,int+i)
end
graphplot(g1,names=1:20)

# %%
function G_generate(C)
    U, Σ, V = svd(C)
    U*diagm(0 => sqrt.(Σ))*U'
end
# Out:
# G_generate (generic function with 1 method)

# %%
function r2N(grid,sol,tspan)
    N=Int(nv(grid))
    Δt=tspan[2]-tspan[1]
    leng=length(sol[1,1:end])
    A=[exp.(sol[i,1:end].*im) for i in 1:N]
    B=zeros(leng)
    for i in 1:N
        B=B.+A[i]
    end
    return (1/Δt)*sum(abs2.((1/N)*B)*Δt/(leng-1))
end
# Out:
# r2N (generic function with 2 methods)

# %% [markdown]
# # Kuramoto Model

# %%
function soltnN(grid,w,k,u0,tspan,σ,ρ)
    E=incidence_matrix(grid;oriented=true)
    n=nv(grid)
    
    function f(du,u,p,t)
        for i in 1:n
            du[i]=w[i]+(k/n)*sum([sin(u[j]-u[i]) for j in 1:n])
        end
    end
    
    function g(du,u,p,t)
        int=Int(nv(grid)/2)
        C=ones(n,n)
        for i in 1:int
            C[(int+1):end,i]=ρ*ones(int)
        end
        for i in (int+1):nv(grid)
            C[1:int,i]=ρ*ones(int)
        end
        G=(σ/sqrt(2))*G_generate(C)
        du.=G
    end
    
    prob=SDEProblem(f,g,u0,tspan,noise_rate_prototype=zeros(n,n))
    sol=solve(prob,ImplicitEM(),dt=0.04)
    return sol
end
# Out:
# soltnN (generic function with 1 method)

# %%
#Run Tonight
w=vcat(-(1/2)*ones(10),(1/2)*ones(10))
tf=3000.0
u0=rand(20)
e(k)=r2N(soltnN(g1,w,k,u0,(0.0,tf),sqrt(2),-1),(0.0,tf))
f(k)=r2N(soltnN(g1,w,k,u0,(0.0,tf),sqrt(2),-0.5),(0.0,tf))
g(k)=r2N(soltnN(g1,w,k,u0,(0.0,tf),sqrt(2),0),(0.0,tf))
h(k)=r2N(soltnN(g1,w,k,u0,(0.0,tf),sqrt(2),0.5),(0.0,tf))
i(k)=r2N(soltnN(g1,w,k,u0,(0.0,tf),sqrt(2),1),(0.0,tf))
ks=LinRange(0,3,150)
edat1=e.(ks)
fdat1=f.(ks)
gdat1=g.(ks)
hdat1=h.(ks)
idat1=i.(ks)
Plots.plot(ks,[edat1,fdat1,gdat1,hdat1,idat1],title= L"\overline{R^2} \textrm{ vs. k for Several ρ}",label=["-1.0" "-0.5" "0" "0.5" "1.0"],xlabel="k",ylabel=L"\overline{R^2}",width=3)

# %%
#Run Tonight
w=vcat(-(1/2)*ones(10),(1/2)*ones(10))
u0=zeros(nv(g1))
tf=1800.0
size=100
xs = [string(i/size) for i = -size:size]
ys = [string(2*i/size) for i = 1:size]
z1 = float((1:size) * reshape(1:(2*size+1), 1, :))
for b in 1:size
    for j in 1:(2*size+1)
        z1[b,j]=r2N(soltnN(g1,w,2*b/size,u0,(0,tf),sqrt(2),(j-size-1)/size),(0.0,tf))
    end
end
Plots.heatmap(xs,ys,z1,aspect_ratio=1)

# %%
#Run Tonight
using Plotly
Plotly.signin("trs3","n3lr1fNnHZO2eMj4FUhv")
Plotly.set_credentials_file(Dict("username"=>"trs3","api_key"=>"n3lr1fNnHZO2eMj4FUhv"))
my_plot = Plotly.plot([Plotly.heatmap(x=xs,y=ys,z=z1')])
post(my_plot)

# %% [markdown]
# # Swing Equation

# %%
function swingsoltnN(grid,D,B,P,M,u0,tspan,σ,ρ)
    E=incidence_matrix(grid;oriented=true)
    n=nv(grid)
    
    function f(du,u,p,t)
        du[1:n]=u[n+1:2n]
        du[n+1:2n] = (-D.*u[n+1:2n] - E*((B/n).*sin.(E'*u[1:n])) + P)./M 
    end
    
    function g(du,u,p,t)
        A=zeros(2n,2n)
        int=Int(n/2)
        C=ρ*ones(n,n)
        C[diagind(C)] .= 1
        for i in 1:int
            C[(int+1):end,i]=ρ*ones(int)
        end
        for i in (int+1):n
            C[1:int,i]=ρ*ones(int)
        end
        G=(σ/sqrt(2))*G_generate(C)
        for i in 1:n
            A[n+i,1:2n]=vcat(zeros(n),G[i,1:n])
        end
        du.=A
    end
    
    prob=SDEProblem(f,g,u0,tspan,noise_rate_prototype=zeros(2n,2n))
    sol=solve(prob,ImplicitEM(),dt=0.04)
    return sol
end
# Out:
# swingsoltnN (generic function with 1 method)

# %%
#Swing Equation Plot with rho covariance
tf=2500.0
D=ones(nv(g1))
M=ones(nv(g1))
P=rand(nv(g1))
P=P.-mean(P)
u0=zeros(2*nv(g1))
a(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),-1),(0.0,tf))
c(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),-0.5),(0.0,tf))
d(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),0),(0.0,tf))
e(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),0.5),(0.0,tf))
f(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),1.0),(0.0,tf))
ks=LinRange(0,3,150)
adat2=a.(ks)
cdat2=c.(ks)
ddat2=d.(ks)
edat2=e.(ks)
fdat2=f.(ks)
Plots.plot(ks,[adat2,cdat2,ddat2,edat2,fdat2],title= L"\overline{R^2} \textrm{ vs. B for Several ρ}",label=["-1.0" "-0.5" "0" "0.5" "1.0"],xlabel="B",ylabel=L"\overline{R^2}",width=3)

# %%
#Swing Equation Plot with rho covariance
tf=2500.0
D=ones(nv(g1))
M=ones(nv(g1))
P=rand(nv(g1))
P=P.-mean(P)
u0=zeros(2*nv(g1))
a(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),-1),(0.0,tf))
c(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),-0.5),(0.0,tf))
d(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),0),(0.0,tf))
e(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),0.5),(0.0,tf))
f(b)=r2N(g1,swingsoltnN(g1,D,b*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),1.0),(0.0,tf))
ks=LinRange(0,3,150)
adat3=a.(ks)
cdat3=c.(ks)
ddat3=d.(ks)
edat3=e.(ks)
fdat3=f.(ks)
Plots.plot(ks,[adat3,cdat3,ddat3,edat3,fdat3],title= L"\overline{R^2} \textrm{ vs. B for Several ρ}",label=["-1.0" "-0.5" "0" "0.5" "1.0"],xlabel="B",ylabel=L"\overline{R^2}",width=3)

# %%
using Plotly
tf=2000.0
D=ones(nv(g1))
M=ones(nv(g1))
P=rand(nv(g1))
P=P.-mean(P)
u0=zeros(2*nv(g1))
size=110
xs2 = [string(i/size) for i = -size:size]
ys2 = [string(2*i/size) for i = 1:size]
z2 = float((1:size) * reshape(1:(2*size+1), 1, :))
for b in 1:size
    for j in 1:(2*size+1)
        z2[b,j]=r2N(swingsoltnN(g1,D,(2*b/size)*ones(ne(g1)),P,M,u0,(0.0,tf),sqrt(2),(j-size-1)/size),(0.0,tf))
    end
end
Plots.heatmap(xs2,ys2,z2,aspect_ratio=1)

# %%
#Run Tonight
using Plotly
Plotly.signin("trs3","n3lr1fNnHZO2eMj4FUhv")
Plotly.set_credentials_file(Dict("username"=>"trs3","api_key"=>"n3lr1fNnHZO2eMj4FUhv"))
my_plot = Plotly.plot([Plotly.heatmap(x=xs2,y=ys2,z=z2')])
post(my_plot)
